# %% [markdown]
# 1. Create a dummy database

# %%
import random

def create_sequence():
  nucleotid_bases = ['A','C','G','T']
  size_sequence = random.randint(10,20)
  new_sequence = [nucleotid_bases[random.randint(0,3)] for i in range(size_sequence)]
  return "".join(new_sequence)

print(create_sequence())
# Out:
# ACGCAACAATCTCGGAA

# %%
def create_database():
  db_size = 50000
  data_base = [create_sequence() for i in range(db_size)]
  return data_base

print(create_database())
# Out:
# ['TAAAGGTCGTTCTGGAGCTT', 'ACCTTCCACCTGTCGCC', 'CGGTCGGGGCT', 'AGGCTCGCTGT', 'ATCGTGACGATTTCCCCGC', 'TGGGTACACGCGAACAACG', 'TGCGCCACATAATCGAGA', 'TCTATCCTCGTCGCATAA', 'CTAGTGAGACATC', 'CAGCAGGAATG', 'GAAAGACGAATGCTCGCTG', 'ACGGTCTCCGA', 'TATAACAGGCGAAACCG', 'TCCCCCTTGCTCCC', 'TGTACCCCGGGAGGGT', 'GCGGAGAGTACCCGC', 'CCATCGGGCCTCTCGTTGA', 'CGATGAGTGCCCCCAGGAAT', 'GCCACGAATAGAAAAAC', 'CCACTGCATCATGAGT', 'ATAACCGAGGGGGAGAAGTC', 'GACACGCGCCAATGAC', 'TGATGTTTGGCCCT', 'AAAGCTTGCACAGTTCCAA', 'TAGTGCAATTATG', 'TCGTCAGGATAGCGACAGAT', 'TTGCACCGGATTTATCCTC', 'CCCCCCTTAACGTCT', 'AATGAACGTAGCGCTATA', 'ACTCTTACCTTC', 'GTGTAAGGACTATTCTA', 'TTCGCGATTTGG', 'TGTTGACCCAGTGCTACAC', 'AAAGCAGTTAGCGACGTCT', 'ACACAAGATTATATAATGG', 'ATGTCTGGGCGAATTCCGGC', 'TTCATCAGCAGCACAAT', 'ACTCCGCTCT', 'CATTCGCCGGGGTGATGCA', 'AACAGACGTTCCTGCCAGC', 'AAATCCCGCCGAGTT', 'TCCGGTATGCGGT', 'GAACGTACCG', 'GGTAGGTTTCC', 'GATGTATATCTTG', 'ATTTGCCACGATATTTGTAG', 'TAAGACGCGGCG', 'TGTAGCAAGACCTCCGG', 'GACAACCTACTT', 'GCGGTAGGGAAACCG', 'CCTTATAAGAAGACCAAAA', 'CATCATGCTGACG', 'AGCCGGGCGCTG', 'GGTACGGATGTAGTG', 'TGCGCTGTCATCA', 'ATCTACCTAGGATTTGACCA', 'GCTGCAAATGGGGTACAAAA', 'AGAAATAGACCATAGCGGTC', 'ACGCCCCCTCACGCC', 'AAGCGCGGAC', 'GTGAAATCGAAC', 'CCAACTGATGATAGTGCC', 'ACGGCCCGCTGCGACATCAT', 'CATACTCTCTACCACTGA', 'TTTAGGGGTTG', 'CGTGCTTCGCCTACGGAAGT', 'CGGACTCAGTACTGCA', 'TGCACCAATTTTAACACC', 'CGAAACAGCACACCTTCGC', 'TTGTGACAGATGGTTG', 'TAGACTCCCAT', 'CCATATGTAATTTAAT', 'GACTGCACTACAGAAAGC', 'TCGAAGTACT', 'TTGTGCACA
'GTGCTCATTTCACT', 'AGCAGACTGTTCCAG', 'ATAAGTATCAACCC', 'GTTCGGCCACTTTGC', 'GATTAGTATCACCAAATA', 'ATGTTCTGCACCCA', 'ATTAATAGCCCGAGGAGAC', 'CAGGATTGTAAGTAGTGC', 'GAATTAATAGCCA', 'AGTCTTCACTG', 'TGCCATGGTGGCCCT', 'GCGGACTCGATGCC', 'GAGATCGGAGTCTAAGTCTC', 'TTGCCAGCGGGCCCAA', 'GAAAACATGTCCTC', 'TGACGAGCAGCTA', 'GTCCATCCGT', 'AGGAAATTTAACTTAACGAC', 'AGGTTCATCTCTG', 'ACGCCCCTTC', 'CGGCCCACCC', 'TCGTCGTTCTC', 'TTTACTACGAGAA', 'ACGATAGAGGATG', 'CTAAGGGAGGTGCTGCATT', 'GAATCTCAGTCT', 'TTCGATTCTAAAGC', 'GATTATCTTCCAC', 'TGTAGCACAGACCATCGAGT', 'ATTACAGCGAAAATATCGA', 'AGGTTGAAATG', 'TGTCTGCATT', 'GTTAAATGCTTGATAGTCTC', 'GTCTGTGCGTGCGGGACTA', 'AGAACAATGCATGAATG', 'CACTCATTGGTATCCCATT', 'CTTAGGACGAATTTT', 'TATTCGGTTTAATACTGTAT', 'GCTCGACCGTGTAATTCT', 'TGCCGACGAGGAGCTGGCTT', 'GAGTCTAGGC', 'GAGG ...

# %%
def get_combinations(n, sequence, bases):
  if n == 1:
    return [sequence+bases[i] for sequence in sequence for i in range(len(bases))]
  else:
    sequence_ = [sequence+bases[i] for sequence in sequence for i in range(len(bases))]
    return get_combinations(n-1, sequence_, bases)

def count_motif(motif, sequences_db):
  count = 0
  for sequence in sequences_db:
    count += sequence.count(motif)
  return count

def get_motif(motif_size, sequences_db):
    nucleotid_bases = ['A','C','G','T']
    combinations = get_combinations(motif_size, [""], nucleotid_bases)
    max_counter = 0
    motif_winner = ""
    for motif_candidate in combinations:
      temp_counter = count_motif(motif_candidate,sequences_db)
      if temp_counter > max_counter:
        max_counter = temp_counter
        motif_winner = motif_candidate
    return motif_winner

motif_Six = get_motif(6, create_database())
motif_Eight = get_motif(8, create_database())

# %%
print(motif_Six)
print(motif_Eight)
# Out:
# ('CCGCAG', 3)

# %%
import math

def shannon_entropy_six(seq):
  counts  = {base: sequence.count(base) for base in ['A','G','C','T']}
  total_bases = sum(counts.values())
  entropy = 0
  for count in counts.values():
    if count > 0:
      prob = count / total_bases
      entropy -= prob * math.prob(log2())
  if entropy > 0.9 or entropy < 2:
    return entropy
  else:
    return shannon_entropy(get_motif(6, create_database()))

  def shannon_entropy_eight(seq):
  counts = {base: sequence.counts(base) for base in ['A','G','C','T']}
  total_bases = sum(counts.values())
  entropy = 0
  for count in counts.values():
    if count > 0:
      prob = count / total_bases
      entropy -= prob * math.prob(log2())
  if entropy > 0.9 or entropy < 2:
    return entropy
  else:
    return shannon_entropy(get_motif(8, create_database()))

print(shannon_entropy_six(motif_Six))
print(shannon_entropy_eight(motif_eight))
